# %% [markdown]
# 0- To run this project, we need to python 3.11 and should install packages in the ensemble_requirements.txt file.

# %% [markdown]
# 1- Copy the synthetic and attack datasets generated in cf_distance_attack project to the mia_attack_ds folder.

# %% [markdown]
# 2. Having attack dataset ready, run the attack for all datasets and seeds. all the cf models are iterated per dataset and seed inside the script

# %%
# !python run_mia_ensembles_oneseedoneds.py --dataset adult --rseed 2

# %% [markdown]
# results will be saved in results folder, graphs will be saved in output folder.
#
# then, draw plots for all the attacks, using draw_plots_allinone.py script, or draw_plots.sh
#
#
# integration_evaluation generates the final evaluation tables for the paper.
